# %% [markdown]
# **1.** Write a program to print your name.

# %%
print("Natte Sai BHarath")
# Out:
# Natte Sai BHarath

# %% [markdown]
# **2.** Write a program for a Single line comment and multi-line comments

# %%
#hai my name is Bharath
""" I am doing Btech.
In Amrita Vishwa Vidyapeetham kerala"""
# Out:
# ' I am doing Btech.\nIn Amrita Vishwa Vidyapeetham kerala'

# %% [markdown]
# **3.** Define variables for different Data Types int, Boolean, char, float, double and print on the
# Console.

# %%
type(10)#int can be used for integers in math
# Out:
# int

# %%
type(True)#Boolean is used for True or False condition
# Out:
# bool

# %%
type("a")# A single letter in dtring is known as char
# Out:
# str

# %%
type(12.0)# A float is used for representing point values
# Out:
# float

# %%
type(1.002451)#A Double type of float with long point values
# Out:
# float

# %% [markdown]
# **4.** Define the local and Global variables with the same name and print both variables and understand the scope of the variables
#
#
#
# *  Variables that are declared within or inside a function block are known as **Local variables**.
# *  **Global variables** are those variables which are declared outside of all the functions or block and can be accessed globally in a program.

# %%
# Here x is example of local variables   and  y is example of Global variables
x = "Hey, I am Global Variable!, I can be used everywhere in the program."   #globalvariable  
def func1():  
    v2="Hey, I am Local Variable!, I can be used within this block only in the program." #localvariable  
    print(v2)  
  
print(x)
func1()
# Out:
# Hey, I am Global Variable!, I can be used everywhere in the program.
# Hey, I am Local Variable!, I can be used within this block only in the program.
