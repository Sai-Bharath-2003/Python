# %% [markdown]
# **1. Create a Dictionary with at least 5 key value pairs of the Student ID and Name**
#
# **1.1.** Adding the values in dictionary
# **1.2.** Updating the values in dictionary
# **1.3.** Accessing the value in dictionary
# **1.4.** Create a nested loop dictionary
# **1.5.** Access the values of nested loop dictionary
# **1.6.** Print the keys present in a particular dictionary
# **1.7.** Delete a value from a dictionary

# %%
Dict = {20051: 'Sai', 20052: 'bharath', 20053: 'Rishi',20054:'Suresh',20055:'Rishideep'}
print(Dict)
# Out:
# {20051: 'Sai', 20052: 'bharath', 20053: 'Rishi', 20054: 'Suresh', 20055: 'Rishideep'}

# %%
Dict[20056] = 'Rani' 
print(Dict)
# Out:
# {20051: 'Sai', 20052: 'bharath', 20053: 'Rishi', 20054: 'Suresh', 20055: 'Rishideep', 20056: 'Rani'}

# %%
Dict['Value_set'] = 20050
print(Dict)
# Out:
# {20051: 'Sai', 20052: 'bharath', 20053: 'Rishi', 20054: 'Suresh', 20055: 'Rishideep', 20056: 'Rani', 'Value_set': 20050}

# %%
print(Dict.get(20053))
# Out:
# Rishi

# %%
Dict['Value_set'] = {'Nested' :{1 : 'A', 2 : 'B'}}
print("\nAdding a Nested loop: ")
print(Dict)
# Out:
# Adding a Nested loop:
# {20051: 'Sai', 20052: 'bharath', 20053: 'Rishi', 20054: 'Suresh', 20055: 'Rishideep', 20056: 'Rani', 'Value_set': {'Nested': {1: 'A', 2: 'B'}}}

# %%
print([Dict['Value_set']['Nested'][1]])
# Out:
# ['A']

# %%
del Dict['Value_set']
print(Dict)
# Out:
# {20051: 'Sai', 20052: 'bharath', 20053: 'Rishi', 20054: 'Suresh', 20055: 'Rishideep', 20056: 'Rani'}
